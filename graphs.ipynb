# %%
import numpy as np
import scipy as sp
import pandas as pd
import scipy.optimize as op
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.dpi'] = 600

data = pd.read_csv('test1.csv', header=0)

plt.bar(data.x, data.y, align='center', width=1)

plt.grid(True)
plt.xlim(xmin = 0, xmax = 10)
plt.savefig('ref/one.png')

# %%
plt.rcParams['figure.dpi'] = 600

data = pd.read_csv('test2.csv', header=0)

plt.bar(data.x, data.y, align='center', width=1) # A bar chart

plt.grid(True)
plt.xlim(xmin = 50, xmax = 150)
plt.savefig('ref/first_ascii.png')

# %%
plt.rcParams['figure.dpi'] = 600

data = pd.read_csv('test3.csv', header=0)

plt.bar(data.x, data.y, align='center', width=1) # A bar chart

plt.grid(True)
plt.xlim(xmin = 0, xmax = 40)
plt.savefig('ref/len.png')

# %%
plt.rcParams['figure.dpi'] = 600

data = pd.read_csv('test4.csv', header=0)

plt.bar(data.x, data.y, align='center', width=1) # A bar chart

plt.grid(True)
plt.xlim(xmin = 0, xmax = 4000)
plt.savefig('ref/sum_ascii.png')

# %%
plt.rcParams['figure.dpi'] = 600

data = pd.read_csv('test5.csv', header=0)

plt.bar(data.x, data.y, align='center', width=1) # A bar chart

plt.grid(True)
plt.xlim(xmin = 0)
plt.savefig('ref/rol.png')

# %%
plt.rcParams['figure.dpi'] = 600

data = pd.read_csv('test6.csv', header=0)

plt.bar(data.x, data.y, align='center', width=1) # A bar chart

plt.grid(True)
plt.xlim(xmin = 0)
plt.savefig('ref/ror.png')

# %%
plt.rcParams['figure.dpi'] = 600

data = pd.read_csv('test7.csv', header=0)

plt.bar(data.x, data.y, align='center', width=1) # A bar chart

plt.grid(True)
plt.xlim(xmin = 0)
plt.savefig('ref/crc32.png')

# %%
plt.rcParams['figure.dpi'] = 600

data = pd.read_csv('test1.csv', header=0)
plt.bar(data.x, data.y, align='center', width=1, color = 'blue', label = 'hash_one()')

data = pd.read_csv('test2.csv', header=0)
plt.bar(data.x, data.y, align='center', width=1, color = 'green', label = 'hash_first_ascii()')

data = pd.read_csv('test3.csv', header=0)
plt.bar(data.x, data.y, align='center', width=1, color = 'orange', label = 'hash_len()')

plt.legend()
plt.grid(True)
plt.xlim(xmin = 0, xmax = 150)
plt.savefig('ref/1.png')

# %%
plt.rcParams['figure.dpi'] = 600

data = pd.read_csv('test4.csv', header=0)
plt.bar(data.x, data.y, align='center', width=1, color = 'red', label = 'hash_sum_ascii()')

data = pd.read_csv('test5.csv', header=0)
plt.bar(data.x, data.y, align='center', width=1, color = 'aqua', label = 'hash_rol()')

data = pd.read_csv('test6.csv', header=0)
plt.bar(data.x, data.y, align='center', width=1, color = 'orange', label = 'hash_ror()')

data = pd.read_csv('test7.csv', header=0)
plt.bar(data.x, data.y, align='center', width=1, color = 'fuchsia', label = 'hash_crc32()')

plt.legend()
plt.grid(True)
plt.xlim(xmin = 0)
plt.savefig('ref/2.png')
